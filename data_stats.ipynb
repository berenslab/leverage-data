# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

# %%
nako_main = '/gpfs01/berens/data/data/medical_imaging/NAKO/nako_decrypted/images_lowres/224'
os.listdir(nako_main)
# Out:
# ['rt_leftnasal', 'rt_rightcentral', 'rt_rightnasal', 'rt_leftcentral']

# %%
import pandas as pd

# %%
rt_leftnasal = os.listdir(os.path.join(nako_main, 'rt_leftnasal'))
rt_leftnasal[0]
# Out:
# '130822.jpg'

# %%
rt_leftcentral = os.listdir(os.path.join(nako_main, 'rt_leftcentral'))
rt_leftcentral[0]
# Out:
# '130822.jpg'

# %%
print(len(rt_leftnasal) + len(rt_leftcentral))
# Out:
# 72360

# %%
print(len(list(set(rt_leftnasal) ))+ len(list(set(rt_leftcentral))))
# Out:
# 72360

# %%
rt_leftnasal.extend(rt_leftcentral)
left_eyes = set(rt_leftnasal)
print(len(left_eyes))
# Out:
# 40653

# %%
rt_rightcentral = os.listdir(os.path.join(nako_main, 'rt_rightcentral'))
rt_rightcentral[0]
# Out:
# '130822.jpg'

# %%
rt_rightnasal = os.listdir(os.path.join(nako_main, 'rt_rightnasal'))
rt_rightnasal[0]
# Out:
# '130822.jpg'

# %%
rt_rightnasal.extend(rt_rightcentral)
right_eyes = set(rt_rightnasal)
print(len(right_eyes))
# Out:
# 44070

# %%
len(left_eyes)+len(right_eyes)
# Out:
# 84723

# %%
print(len(rt_rightcentral) + len(rt_rightnasal))
# Out:
# 80774
